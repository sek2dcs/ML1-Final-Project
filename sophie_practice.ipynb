# %%
# %pip uninstall -y tensorflow tensorflow-macos mediapipe protobuf opencv-python keras tensorboard numpy
# Out:
# WARNING: Skipping tensorflow as it is not installed.
# Found existing installation: tensorflow-macos 2.15.0
# Uninstalling tensorflow-macos-2.15.0:
#   Successfully uninstalled tensorflow-macos-2.15.0
# Found existing installation: mediapipe 0.10.9
# Uninstalling mediapipe-0.10.9:
#   Successfully uninstalled mediapipe-0.10.9
# Found existing installation: protobuf 3.20.3
# Uninstalling protobuf-3.20.3:
#   Successfully uninstalled protobuf-3.20.3
# Found existing installation: opencv-python 4.8.0.74
# Uninstalling opencv-python-4.8.0.74:
#   Successfully uninstalled opencv-python-4.8.0.74
# Found existing installation: keras 2.15.0
# Uninstalling keras-2.15.0:
#   Successfully uninstalled keras-2.15.0
# Found existing installation: tensorboard 2.15.2
# Uninstalling tensorboard-2.15.2:
#   Successfully uninstalled tensorboard-2.15.2
# Found existing installation: numpy 1.26.4
# Uninstalling numpy-1.26.4:
#   Successfully uninstalled numpy-1.26.4
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install "numpy==1.26.4" --force-reinstall --no-deps --ignore-installed
# Out:
# Collecting numpy==1.26.4
#   Using cached numpy-1.26.4-cp310-cp310-macosx_11_0_arm64.whl.metadata (61 kB)
# Using cached numpy-1.26.4-cp310-cp310-macosx_11_0_arm64.whl (14.0 MB)
# Installing collected packages: numpy
# Successfully installed numpy-1.26.4
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install "tensorflow-macos==2.15.0" "mediapipe==0.10.9" "protobuf==3.20.3" "opencv-python==4.8.0.74" "keras<3.0"
# Out:
# Collecting tensorflow-macos==2.15.0
#   Using cached tensorflow_macos-2.15.0-cp310-cp310-macosx_12_0_arm64.whl.metadata (4.2 kB)
# Collecting mediapipe==0.10.9
#   Using cached mediapipe-0.10.9-cp310-cp310-macosx_11_0_universal2.whl.metadata (9.6 kB)
# Collecting protobuf==3.20.3
#   Using cached protobuf-3.20.3-py2.py3-none-any.whl.metadata (720 bytes)
# Collecting opencv-python==4.8.0.74
#   Using cached opencv_python-4.8.0.74-cp37-abi3-macosx_11_0_arm64.whl.metadata (19 kB)
# Collecting keras<3.0
#   Using cached keras-2.15.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/sophiekim/miniforge3/envs/tf_m4/lib/python3.10/site-packages (from tensorflow-macos==2.15.0) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/sophiekim/miniforge3/envs/tf_m4/lib/python3.10/site-packages (from tensorflow-macos==2.15.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /Users/sophiekim/miniforge3/envs/tf_m4/lib/python3.10/site-packages (from tensorflow-macos==2.15.0) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/sophiekim/miniforge3/envs/tf_m4/lib/python3.10/site-packages (from tensorflow-macos==2.15.0) (0.7.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/sophiekim/miniforge3/envs/tf_m4/lib/python3.10/site-packages (from tensorflow-macos==2.15.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /Users/sophiekim/miniforge3/envs/tf_m4/lib/python3.10/site-packages (from tensorflow-macos==2.15.0) (3.15.1)
# Requirement already satisfied: libclang>=13.0.0 in /Users/sophiekim/miniforge3/envs/tf_m4/lib/python3.10/site-packages (from tensorflow-macos==2.15.0) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /Users/sophiekim/miniforge3/envs/tf_m4/lib/python3.10/site-packages (from tensorflow-macos==2.15.0) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /Users/sophiekim/miniforge3/envs/tf_m4/lib/python3.10/site-packages (from tensorflow-macos==2.15.0) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/sophiekim/miniforge3/envs/tf_m4/lib/python3.10/site-packages (from tensorflow-macos==2.15.0) (3.4.0)
# Requirement already satisfied: packaging in /Users/sophiekim/miniforge3/envs/tf_m4/lib/python3.10/site-packages (from tensorflow-macos==2.15.0) (25.0)
# Requirement already satisfied: setuptools in /Users/sophiekim/miniforge3/envs/tf_m4/lib/python3.10/site-packages (from tensorflow-macos==2.15.0) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in /Users/sophiekim/miniforge3/envs/tf_m4/lib/python3.10/site-packages (from tensorflow-macos==2.15.0) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/sophiekim/miniforge3/envs/tf_m4/lib/python3.10/site-packages (from tensorflow-macos==2.15.0) (3.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/sophiekim/miniforge3/envs/tf_m4/lib/python3.10/site-packages (from tensorflow-macos==2.15.0) (4.15.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /Users/sophiekim/miniforge3/envs/tf_m4/lib/python3.10/site-packages (from tensorflow-macos==2.15.0) (1.14.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/sophiekim/miniforge3/envs/tf_m4/lib/python3.10/site-packages (from tensorflow-macos==2.15.0) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/sophiekim/miniforge3/envs/tf_m4/lib/python3.10/site-packages (from tensorflow-macos==2.15.0) (1.76.0)
# Collecting tensorboard<2.16,>=2.15 (from tensorflow-macos==2.15.0)
#   Using cached tensorboard-2.15.2-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /Users/sophiekim/miniforge3/envs/tf_m4/lib/python3.10/site-packages (from tensorflow-macos==2.15.0) (2.15.0)
# Requirement already satisfied: attrs>=19.1.0 in /Users/sophiekim/miniforge3/envs/tf_m4/lib/python3.10/site-packages (from mediapipe==0.10.9) (25.4.0)
# Requirement already satisfied: matplotlib in /Users/sophiekim/miniforge3/envs/tf_m4/lib/python3.10/site-packages (from mediapipe==0.10.9) (3.10.7)
# Requirement already satisfied: opencv-contrib-python in /Users/sophiekim/miniforge3/envs/tf_m4/lib/python3.10/site-packages (from mediapipe==0.10.9) (4.11.0.86)
# Requirement already satisfied: sounddevice>=0.4.4 in /Users/sophiekim/miniforge3/envs/tf_m4/lib/python3.10/site-packages (from mediapipe==0.10.9) (0.5.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/sophiekim/miniforge3/envs/tf_m4/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0) (2.41.1)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /Users/sophiekim/miniforge3/envs/tf_m4/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0) (1.2.3)
# Requirement already satisfied: markdown>=2.6.8 in /Users/sophiekim/miniforge3/envs/tf_m4/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0) (3.10)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/sophiekim/miniforge3/envs/tf_m4/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0) (2.32.5)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/sophiekim/miniforge3/envs/tf_m4/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/sophiekim/miniforge3/envs/tf_m4/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0) (3.1.4)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /Users/sophiekim/miniforge3/envs/tf_m4/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/sophiekim/miniforge3/envs/tf_m4/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/sophiekim/miniforge3/envs/tf_m4/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/sophiekim/miniforge3/envs/tf_m4/lib/python3.10/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0) (2.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/sophiekim/miniforge3/envs/tf_m4/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sophiekim/miniforge3/envs/tf_m4/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/sophiekim/miniforge3/envs/tf_m4/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sophiekim/miniforge3/envs/tf_m4/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0) (2025.11.12)
# Requirement already satisfied: pyasn1>=0.1.3 in /Users/sophiekim/miniforge3/envs/tf_m4/lib/python3.10/site-packages (from rsa<5,>=3.1.4->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0) (0.6.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/sophiekim/miniforge3/envs/tf_m4/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow-macos==2.15.0) (0.45.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/sophiekim/miniforge3/envs/tf_m4/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0) (3.3.1)
# Requirement already satisfied: CFFI>=1.0 in /Users/sophiekim/miniforge3/envs/tf_m4/lib/python3.10/site-packages (from sounddevice>=0.4.4->mediapipe==0.10.9) (2.0.0)
# Requirement already satisfied: pycparser in /Users/sophiekim/miniforge3/envs/tf_m4/lib/python3.10/site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe==0.10.9) (2.23)
# Requirement already satisfied: markupsafe>=2.1.1 in /Users/sophiekim/miniforge3/envs/tf_m4/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/sophiekim/miniforge3/envs/tf_m4/lib/python3.10/site-packages (from matplotlib->mediapipe==0.10.9) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/sophiekim/miniforge3/envs/tf_m4/lib/python3.10/site-packages (from matplotlib->mediapipe==0.10.9) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/sophiekim/miniforge3/envs/tf_m4/lib/python3.10/site-packages (from matplotlib->mediapipe==0.10.9) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/sophiekim/miniforge3/envs/tf_m4/lib/python3.10/site-packages (from matplotlib->mediapipe==0.10.9) (1.4.9)
# Requirement already satisfied: pillow>=8 in /Users/sophiekim/miniforge3/envs/tf_m4/lib/python3.10/site-packages (from matplotlib->mediapipe==0.10.9) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /Users/sophiekim/miniforge3/envs/tf_m4/lib/python3.10/site-packages (from matplotlib->mediapipe==0.10.9) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/sophiekim/miniforge3/envs/tf_m4/lib/python3.10/site-packages (from matplotlib->mediapipe==0.10.9) (2.9.0.post0)
# Using cached tensorflow_macos-2.15.0-cp310-cp310-macosx_12_0_arm64.whl (208.8 MB)
# Using cached protobuf-3.20.3-py2.py3-none-any.whl (162 kB)
# Using cached mediapipe-0.10.9-cp310-cp310-macosx_11_0_universal2.whl (47.1 MB)
# Using cached opencv_python-4.8.0.74-cp37-abi3-macosx_11_0_arm64.whl (33.1 MB)
# Using cached keras-2.15.0-py3-none-any.whl (1.7 MB)
# Using cached tensorboard-2.15.2-py3-none-any.whl (5.5 MB)
# Installing collected packages: protobuf, opencv-python, keras, mediapipe, tensorboard, tensorflow-macos
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [tensorflow-macos][tensorflow-macos]
# Successfully installed keras-2.15.0 mediapipe-0.10.9 opencv-python-4.8.0.74 protobuf-3.20.3 tensorboard-2.15.2 tensorflow-macos-2.15.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip uninstall -y jax jaxlib
# Out:
# Found existing installation: jax 0.4.13
# Uninstalling jax-0.4.13:
#   Successfully uninstalled jax-0.4.13
# Found existing installation: jaxlib 0.4.13
# Uninstalling jaxlib-0.4.13:
#   Successfully uninstalled jaxlib-0.4.13
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install "jax==0.4.13" "jaxlib==0.4.13" "ml_dtypes==0.2.0"
# Out:
# Collecting jax==0.4.13
#   Using cached jax-0.4.13-py3-none-any.whl
# Collecting jaxlib==0.4.13
#   Using cached jaxlib-0.4.13-cp310-cp310-macosx_11_0_arm64.whl.metadata (2.1 kB)
# Requirement already satisfied: ml_dtypes==0.2.0 in /Users/sophiekim/miniforge3/envs/tf_m4/lib/python3.10/site-packages (0.2.0)
# Requirement already satisfied: numpy>=1.21 in /Users/sophiekim/miniforge3/envs/tf_m4/lib/python3.10/site-packages (from jax==0.4.13) (1.26.4)
# Requirement already satisfied: opt_einsum in /Users/sophiekim/miniforge3/envs/tf_m4/lib/python3.10/site-packages (from jax==0.4.13) (3.4.0)
# Requirement already satisfied: scipy>=1.7 in /Users/sophiekim/miniforge3/envs/tf_m4/lib/python3.10/site-packages (from jax==0.4.13) (1.15.2)
# Using cached jaxlib-0.4.13-cp310-cp310-macosx_11_0_arm64.whl (60.5 MB)
# Installing collected packages: jaxlib, jax
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [jax]1/2 [jax]
# Successfully installed jax-0.4.13 jaxlib-0.4.13
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import pandas as pd
import numpy as np
import mediapipe as mp
from pathlib import Path
import math

# %%
# getting data from
PROJECT_ROOT = Path("/Users/sophiekim/Desktop/msds/ds 6021/ML1-Final-Project")
IMAGES_DIR = PROJECT_ROOT / "faces"
CSV_FILE = PROJECT_ROOT / "Headshots for ML(Sheet1).csv"
VISUAL_DIR = PROJECT_ROOT / "visualized_faces"
VISUAL_DIR.mkdir(exist_ok=True)
PHI = 1.618

# loading data
print("Loading metadata...")
name_to_metadata = {}

if CSV_FILE.exists():
    meta_df = pd.read_csv(CSV_FILE)
    # rename cols to standardized lowercase keys
    meta_df = meta_df.rename(columns={
        "Email": "email",
        "Name": "name",
        "race?": "race",
        "gender?": "gender"
    })

    for _, row in meta_df.iterrows():
        raw_name = str(row["name"]).strip()
        if raw_name and raw_name.lower() != "nan":
            name_to_metadata[raw_name] = {
                "name": raw_name,
                "email": str(row["email"]).strip() if pd.notna(row["email"]) else "",
                "race": str(row["race"]).strip() if pd.notna(row["race"]) else "Unknown",
                "gender": str(row["gender"]).strip() if pd.notna(row["gender"]) else "Unknown"
            }
    print(f"Loaded {len(name_to_metadata)} people from CSV")
else:
    print("Original CSV file not found")

def get_metadata(filename):
    stem = Path(filename).stem.lower()
    
    # see if it can get the person's name from the file name
    for real_name, data in name_to_metadata.items():
        if real_name.lower() in stem:
            return data
            
    # default if not found
    return {"name": "Unknown", "email": "", "race": "", "gender": ""}

# mediapipe AI face mesh 
mp_face_mesh = mp.solutions.face_mesh
face_mesh = mp_face_mesh.FaceMesh(
    static_image_mode=True,
    max_num_faces=1,
    refine_landmarks=True,
    min_detection_confidence=0.01, # low confidence so it can get everyone's face
    min_tracking_confidence=0.01
)

def get_landmarks(img):
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    results = face_mesh.process(img_rgb)
    if results.multi_face_landmarks:
        return results.multi_face_landmarks[0].landmark
    return None

def calculate_features(landmarks, w, h):
    def get_pt(idx): return np.array([landmarks[idx].x * w, landmarks[idx].y * h])

    # pixel distance
    face_height = np.linalg.norm(get_pt(10) - get_pt(152))
    face_width = np.linalg.norm(get_pt(234) - get_pt(454))
    pupil_dist = np.linalg.norm(get_pt(468) - get_pt(473))
    avg_eye_w = (np.linalg.norm(get_pt(33)-get_pt(133)) + np.linalg.norm(get_pt(263)-get_pt(362))) / 2
    nose_width = np.linalg.norm(get_pt(102) - get_pt(292))
    mouth_width = np.linalg.norm(get_pt(61) - get_pt(291))

    if avg_eye_w == 0 or nose_width == 0: return None


    face_ratio = face_height / face_width
    mouth_nose_ratio = mouth_width / nose_width
    eye_ratio = pupil_dist / avg_eye_w
    
    # calculate how close it is to 1.618
    errors = [abs(face_ratio - PHI)/PHI, abs(mouth_nose_ratio - PHI)/PHI]
    score = (1 - (sum(errors) / len(errors))) * 100

    return {
        "face_ratio": face_ratio,
        "mouth_nose_ratio": mouth_nose_ratio,
        "eye_ratio": eye_ratio,
        "golden_score": score,
        "face_height": face_height,
        "face_width": face_width,
        "nose_width": nose_width,
        "mouth_width": mouth_width
    }

def draw_visuals(img, landmarks, feats, metadata):
    img_disp = img.copy()
    h, w, _ = img.shape
    def pt(idx): return (int(landmarks[idx].x * w), int(landmarks[idx].y * h))

    # lines
    cv2.line(img_disp, pt(10), pt(152), (255, 0, 0), 2)
    cv2.line(img_disp, pt(234), pt(454), (255, 0, 0), 2)
    cv2.line(img_disp, pt(102), pt(292), (0, 255, 255), 2)
    cv2.line(img_disp, pt(61), pt(291), (255, 0, 255), 2)

    # info box on pic
    cv2.rectangle(img_disp, (0, 0), (450, 190), (0,0,0), -1)
    def txt(t, y, c=(255,255,255)): 
        cv2.putText(img_disp, t, (10, y), cv2.FONT_HERSHEY_SIMPLEX, 0.6, c, 2)

    txt(f"Name: {metadata['name']}", 30, (0, 255, 255))
    txt(f"Email: {metadata['email']}", 60, (200, 200, 200))  # <--- Shows Email on Image
    txt(f"Score: {feats['golden_score']:.1f}%", 90, (0, 255, 0))
    txt(f"Face Ratio: {feats['face_ratio']:.2f}", 120)
    txt(f"Mouth/Nose: {feats['mouth_nose_ratio']:.2f}", 150)

    return img_disp

# go!
rows = []
all_files = []
for ext in ['*.jpg', '*.jpeg', '*.png', '*.bmp', '*.tiff', '*.webp']:
    all_files.extend(IMAGES_DIR.rglob(ext))
    all_files.extend(IMAGES_DIR.rglob(ext.upper()))
image_paths = sorted(list(set(all_files)))

print(f"🚀 Processing {len(image_paths)} images...")

for img_path in image_paths:
    if img_path.name.startswith('.'): continue
    
    # getting people name and stuff 
    meta = get_metadata(img_path.name)
    
    row = {
        "filename": img_path.name,
        "name": meta['name'],
        "email": meta['email'],   
        "race": meta['race'],
        "gender": meta['gender'],
        "status": "No Face Detected",
        "golden_score": None
    }

    # load image
    try:
        img = cv2.imread(str(img_path))
        if img is None: raise ValueError("Load failed")
    except:
        row["status"] = "Corrupt File"
        rows.append(row)
        continue

    h, w, _ = img.shape
    landmarks = get_landmarks(img)

    if landmarks:
        feats = calculate_features(landmarks, w, h)
        if feats:
            row.update(feats)
            row["status"] = "Success"
            
            # Create Visualized Image
            vis_img = draw_visuals(img, landmarks, feats, meta)
            save_vis_path = VISUAL_DIR / f"marked_{img_path.name}"
            cv2.imwrite(str(save_vis_path), vis_img)
            
            print(f"✅ {meta['name']} - Score: {feats['golden_score']:.1f}%")
        else:
            print(f"⚠️ Math Error: {img_path.name}")
    else:
        cv2.putText(img, "NO FACE DETECTED", (50, h//2), cv2.FONT_HERSHEY_SIMPLEX, 1.5, (0,0,255), 4)
        cv2.imwrite(str(VISUAL_DIR / f"failed_{img_path.name}"), img)
        print(f"❌ No Face: {img_path.name}")

    rows.append(row)

# save df 
df = pd.DataFrame(rows)
output_path = PROJECT_ROOT / "final_data_with_demographics.csv"
df.to_csv(output_path, index=False)

print(f"\n🎉 Done!")
print(f"Visualizations saved to: {VISUAL_DIR}")
print(f"Data saved to: {output_path}")
# Out:
# Loading metadata...
# Loaded 51 people from CSV
# 🚀 Processing 54 images...
# ✅ Sophie Kim - Score: 72.3%
# ✅ Unknown - Score: 65.4%
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1765480263.897495       1 gl_context.cc:344] GL version: 2.1 (2.1 Metal - 89.4), renderer: Apple M4
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# ✅ Sabine Segaloff - Score: 70.7%
# ✅ Sophie Kim - Score: 69.1%
# ✅ Anna Li - Score: 72.3%
# ✅ Aniyah McWilliams - Score: 69.9%
# ✅ Erin Siedlecki - Score: 70.8%
# ✅ Ethan Meidinger - Score: 72.9%
# ✅ Marissa Burton - Score: 70.5%
# ✅ Grace George - Score: 69.2%
# ✅ Randa Ampah - Score: 77.2%
# ✅ Isabella Lu - Score: 71.3%
# ✅ Sophie Kim - Score: 74.4%
# ✅ Unknown - Score: 66.7%
# ✅ Thomas Blalock - Score: 70.3%
# ✅ Mauricio Torres - Score: 74.0%
# ✅ Jack Joy - Score: 69.7%
# ✅ Sophie Kim - Score: 69.8%
# ✅ Natalie Seah - Score: 73.8%
# ✅ Andrew Pavlak - Score: 71.0%
# ✅ Mason Earp - Score: 74.0%
# ✅ Mohini Gupta - Score: 72.7%
# ✅ Timothy Yeh - Score: 70.0%
# ✅ Harry Millspaugh - Score: 65.8%
# ✅ Sheyi Faparusi - Score: 67.1%
# ✅ Caroline Kranefuss - Score: 75.3%
# ✅ Terry Luedtke - Score: 65.0%
# ✅ Aiden Rocha - Score: 65.1%
# ✅ Tianyin Mao - Score: 65.9%
# ✅ Lino De Ros - Score: 75.9%
# ✅ Brooke Lumpkin - Score: 73.2%
# ✅ Reed Baumgardner - Score: 70.7%
# ✅ Jackson Kennedy - Score: 67.2%
# ✅ Edward Anderson - Score: 72.4%
# ✅ Maggie Crowner - Score: 70.5%
# ✅ Karina Mehta - Score: 70.0%
# ✅ Shiraz Robinson - Score: 72.6%
# ✅ Nicholas Thornton - Score: 73.3%
# ✅ Hudson Noyes - Score: 66.5%
# ✅ Yani Iben - Score: 64.6%
# ✅ Razan Habboub - Score: 71.3%
# ✅ Shaveen Saadee - Score: 76.7%
# ✅ Unknown - Score: 76.8%
# ✅ Jeffrey Zhang - Score: 65.2%
# ✅ Jeffrey Zhang - Score: 65.2%
# ✅ Emily Garman - Score: 70.8%
# ✅ Jillian Howe - Score: 73.1%
# ✅ Adam Chow - Score: 67.5%
# ✅ Nathan Todd - Score: 65.7%
# ✅ Nathan Wan - Score: 64.0%
# ✅ James Sweat - Score: 72.8%
# ✅ Sophie Kim - Score: 66.9%
# ✅ Samuel Kunitz-Levy - Score: 72.3%
# ✅ Chloe Barnes - Score: 65.8%
#
# 🎉 Done!
# Visualizations saved to: /Users/sophiekim/Desktop/msds/ds 6021/ML1-Final-Project/visualized_faces
# Data saved to: /Users/sophiekim/Desktop/msds/ds 6021/ML1-Final-Project/final_data_with_demographics.csv
